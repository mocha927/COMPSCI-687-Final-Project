# %%
import gymnasium as gym
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
import ale_py
import os

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
env = gym.make("ALE/Pong-v5")
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "mps" if torch.backends.mps.is_available() else
    "cpu"
)

device
# Out:
# device(type='cuda')

# %%
SAVE_DIR = '.'

# %%
class DQN(nn.Module):
    def __init__(self, input_shape, n_actions):
        super(DQN, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )

        conv_out_size = self._get_conv_out(input_shape)

        self.fc = nn.Sequential(
            nn.Linear(conv_out_size, 512),
            nn.ReLU(),
            nn.Linear(512, n_actions)
        )

    def _get_conv_out(self, shape):
        o = self.conv(torch.zeros(1, *shape))
        return int(np.prod(o.size()))

    def forward(self, x):
        conv_out = self.conv(x).view(x.size()[0], -1)
        return self.fc(conv_out)

class DNN(nn.Module):
    def __init__(self, input_dim, n_actions):
        super(DNN, self).__init__()

        self.net = nn.Sequential(
            nn.Linear(input_dim, 32),
            nn.ReLU(),
            nn.Linear(32, n_actions),
            nn.Softmax(dim=-1)
        )

    def forward(self, x):
        return self.net(x)

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        state, action, reward, next_state, done = zip(*random.sample(self.buffer, batch_size))
        return (torch.FloatTensor(np.float32(state)),
                torch.LongTensor(action),
                torch.FloatTensor(reward),
                torch.FloatTensor(np.float32(next_state)),
                torch.BoolTensor(done))

    def __len__(self):
        return len(self.buffer)

class DQNAgent:
    def __init__(self, state_shape, n_actions, device="cpu"):
        self.device = device
        self.n_actions = n_actions
        self.state_shape = state_shape

        self.policy_net = DQN(state_shape, n_actions).to(device) # for Pong
        self.target_net = DQN(state_shape, n_actions).to(device) # for Pong

        self.target_net.load_state_dict(self.policy_net.state_dict())

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=1e-4)
        self.memory = ReplayBuffer(100000)

        self.batch_size = 32
        self.gamma = 0.99
        self.eps_start = 1.0
        self.eps_end = 0.02
        self.eps_decay = 100000
        self.target_update = 1000
        self.steps_done = 0

    def select_action(self, state):
        eps_threshold = self.eps_end + (self.eps_start - self.eps_end) * math.exp(-1. * self.steps_done / self.eps_decay)
        self.steps_done += 1

        if random.random() > eps_threshold:
            with torch.no_grad():
                state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
                q_values = self.policy_net(state)
                return q_values.max(1)[1].item()
        else:
            return random.randrange(self.n_actions)

    def select_greedy_action(self, state):
        with torch.no_grad():
            state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
            q_values = self.policy_net(state)
            return q_values.max(1)[1].item()

    def optimize_model(self):
        if len(self.memory) < self.batch_size:
            return

        state_batch, action_batch, reward_batch, next_state_batch, done_batch = self.memory.sample(self.batch_size)

        state_batch = state_batch.to(self.device)
        action_batch = action_batch.to(self.device)
        reward_batch = reward_batch.to(self.device)
        next_state_batch = next_state_batch.to(self.device)
        done_batch = done_batch.to(self.device)

        current_q_values = self.policy_net(state_batch).gather(1, action_batch.unsqueeze(1))

        with torch.no_grad():
            # get indices of best action taken by policy network at next state(s)
            next_action_indices = self.policy_net(next_state_batch).max(1)[1]

            # compute q values for target network
            next_state_values = self.target_net(next_state_batch)

            # uses indices from policy network to corresponding q values estimated from target network
            next_state_values = next_state_values.gather(1, next_action_indices.unsqueeze(1)).squeeze()

            next_state_values[done_batch] = 0.0
            expected_q_values = reward_batch + self.gamma * next_state_values

        loss = nn.SmoothL1Loss()(current_q_values.squeeze(), expected_q_values)

        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 100)
        self.optimizer.step()

        return loss.item()

def preprocess_frame(frame):
    frame = frame[35:195]  # Crop
    frame = frame[::2, ::2]  # Downsample
    frame = frame.mean(axis=2)  # Convert to grayscale
    frame = frame.astype(np.float32) / 255.0
    return frame

def train(agent, env, num_episodes=1000):
    frame_stack = deque(maxlen=4)
    losses = []

    for episode in range(num_episodes):
        frame, _ = env.reset()
        frame = preprocess_frame(frame) # comment out for cartpole

        for _ in range(4):
            frame_stack.append(frame)

        total_reward = 0
        done = False
        truncated = False

        while not (done or truncated):
            state = np.array(frame_stack) # for Pong
            action = agent.select_action(state)

            next_frame, reward, done, truncated, _ = env.step(action)
            next_frame = preprocess_frame(next_frame)
            frame_stack.append(next_frame)
            next_state = np.array(frame_stack) # for Pong

            agent.memory.push(state, action, reward, next_state, bool(done))

            if len(agent.memory) >= agent.batch_size:
                loss = agent.optimize_model()

            total_reward += reward

            if agent.steps_done % agent.target_update == 0:
                agent.target_net.load_state_dict(agent.policy_net.state_dict())

        print(f"Episode {episode}, Total Reward: {total_reward}, Steps: {agent.steps_done}")
        losses.append(total_reward)

        # Save model periodically
        if episode % 100 == 99:
            torch.save(agent.policy_net.state_dict(), f"{SAVE_DIR}/pong_dqn_episode_{episode}.pth")

        if episode == num_episodes - 1:
            torch.save(agent.policy_net.state_dict(), f"{SAVE_DIR}/pong_dqn_episode_end.pth")

    return agent, losses

# %%
class DDQNAgent(DQNAgent):
  # override previous 'optimize_model' method
  def optimize_model(self):
      if len(self.memory) < self.batch_size:
          return

      state_batch, action_batch, reward_batch, next_state_batch, done_batch = self.memory.sample(self.batch_size)

      state_batch = state_batch.to(self.device)
      action_batch = action_batch.to(self.device)
      reward_batch = reward_batch.to(self.device)
      next_state_batch = next_state_batch.to(self.device)
      done_batch = done_batch.to(self.device)

      current_q_values = self.policy_net(state_batch).gather(1, action_batch.unsqueeze(1))

      with torch.no_grad():
          # get indices of best action taken by policy network at next state(s)
          next_action_indices = self.policy_net(next_state_batch).max(1)[1]

          # compute q values for target network
          next_state_values = self.target_net(next_state_batch)

          # uses indices from policy network to corresponding q values estimated from target network
          next_state_values = next_state_values.gather(1, next_action_indices.unsqueeze(1)).squeeze()

          next_state_values[done_batch] = 0.0
          expected_q_values = reward_batch + self.gamma * next_state_values

      loss = nn.SmoothL1Loss()(current_q_values.squeeze(), expected_q_values)

      self.optimizer.zero_grad()
      loss.backward()
      torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 100)
      self.optimizer.step()

      return loss.item()

# %%
state_shape = (4, 80, 80)  # 4 frames stacked, 80x80 each; for Pong
n_actions = env.action_space.n # for Pong

agent = DDQNAgent(state_shape, n_actions, device)

# %%
# load the model
if os.path.exists("pong_dqn_episode_end.pth"):
    agent.policy_net.load_state_dict(torch.load("pong_dqn_episode_end.pth"))
    losses = np.load("losses.npy")
else:
    agent, losses = train(agent, env, num_episodes=1000)
    np.save(SAVE_DIR + "/" + "losses.npy", np.array(losses))
# Out:
# Episode 0, Total Reward: 9.0, Steps: 9
# Episode 1, Total Reward: 17.0, Steps: 26
# Episode 2, Total Reward: 33.0, Steps: 59
# Episode 3, Total Reward: 13.0, Steps: 72
# Episode 4, Total Reward: 61.0, Steps: 133
# Episode 5, Total Reward: 14.0, Steps: 147
# Episode 6, Total Reward: 31.0, Steps: 178
# Episode 7, Total Reward: 14.0, Steps: 192
# Episode 8, Total Reward: 14.0, Steps: 206
# Episode 9, Total Reward: 12.0, Steps: 218
# Episode 10, Total Reward: 11.0, Steps: 229
# Episode 11, Total Reward: 24.0, Steps: 253
# Episode 12, Total Reward: 11.0, Steps: 264
# Episode 13, Total Reward: 21.0, Steps: 285
# Episode 14, Total Reward: 13.0, Steps: 298
# Episode 15, Total Reward: 12.0, Steps: 310
# Episode 16, Total Reward: 17.0, Steps: 327
# Episode 17, Total Reward: 11.0, Steps: 338
# Episode 18, Total Reward: 12.0, Steps: 350
# Episode 19, Total Reward: 15.0, Steps: 365
# Episode 20, Total Reward: 18.0, Steps: 383
# Episode 21, Total Reward: 25.0, Steps: 408
# Episode 22, Total Reward: 25.0, Steps: 433
# Episode 23, Total Reward: 49.0, Steps: 482
# Episode 24, Total Reward: 24.0, Steps: 506
# Episode 25, Total Reward: 35.0, Steps: 541
# Episode 26, Total Reward: 23.0, Steps: 564
# Episode 27, Total Reward: 19.0, Steps: 583
# Episode 28, Total Reward: 11.0, Steps: 594
# Episode 29, Total Reward: 41.0, Steps: 635
# Episode 30, Total Reward: 15.0, Steps: 650
# Episode 31, Total Reward: 15.0, Steps: 665
# Episode 32, Total Reward: 24.0, Steps: 689
# Episode 33, Total Reward: 21.0, Steps: 710
# Episode 34, Total Reward: 29.0, Steps: 739
# Episode 35, Total Reward: 32.0, Steps: 771
# Episode 36, Total Reward: 27.0, Steps: 798
# Episode 37, Total Reward: 13.0, Steps: 811
# Episode 38, Total Reward: 12.0, Steps: 823
# Episode 39, Total Reward: 17.0, Steps: 840
# Episode 40, Total Reward: 15.0, Steps: 855
# Episode 41, Total Reward: 18.0, Steps: 873
# Episode 42, Total Reward: 15.0, Steps: 888
# Episode 43, Total Reward: 16.0, Steps: 904
# Episode 44, Total Reward: 17.0, Steps: 921
# Episode 45, Total Reward: 34.0, Steps: 955
# Episode 46, Total Reward: 20.0, Steps: 975
# Episode 47, Total Reward: 9.0, Steps: 984
# Episode 48, Total Reward: 16.0, Steps: 1000
# Episode 49, Total Reward: 21.0, Steps: 1021
# Episode 50, Total Reward: 26.0, Steps: 1047
# Episode 51, Total Reward: 20.0, Steps: 1067
# Episode 52, Total Reward: 19.0, Steps: 1086
# Episode 53, Total Reward: 17.0, Steps: 1103
# Episode 54, Total Reward: 42.0, Steps: 1145
# Episode 55, Total Reward: 37.0, Steps: 1182
# Episode 56, Total Reward: 12.0, Steps: 1194
# Episode 57, Total Reward: 44.0, Steps: 1238
# Episode 58, Total Reward: 12.0, Steps: 1250
# Episode 59, Total Reward: 13.0, Steps: 1263
# Episode 60, Total Reward: 11.0, Steps: 1274
# Episode 61, Total Reward: 36.0, Steps: 1310
# Episode 62, Total Reward: 13.0, Steps: 1323
# Episode 63, Total Reward: 11.0, Steps: 1334
# Episode 64, Total Reward: 27.0, Steps: 1361
# Episode 65, Total Reward: 27.0, Steps: 1388
# Episode 66, Total Reward: 17.0, Steps: 1405
# Episode 67, Total Reward: 15.0, Steps: 1420
# Episode 68, Total Reward: 13.0, Steps: 1433
# Episode 69, Total Reward: 30.0, Steps: 1463
# Episode 70, Total Reward: 13.0, Steps: 1476
# Episode 71, Total Reward: 11.0, Steps: 1487
# Episode 72, Total Reward: 17.0, Steps: 1504
# Episode 73, Total Reward: 11.0, Steps: 1515
# Episode 74, Total Reward: 11.0, Steps: 1526
# Episode 75, Total Reward: 20.0, Steps: 1546
# Episode 76, Total Reward: 21.0, Steps: 1567
# Episode 77, Total Reward: 11.0, Steps: 1578
# Episode 78, Total Reward: 28.0, Steps: 1606
# Episode 79, Total Reward: 19.0, Steps: 1625
# Episode 80, Total Reward: 10.0, Steps: 1635
# Episode 81, Total Reward: 15.0, Steps: 1650
# Episode 82, Total Reward: 18.0, Steps: 1668
# Episode 83, Total Reward: 14.0, Steps: 1682
# Episode 84, Total Reward: 48.0, Steps: 1730
# Episode 85, Total Reward: 32.0, Steps: 1762
# Episode 86, Total Reward: 17.0, Steps: 1779
# Episode 87, Total Reward: 33.0, Steps: 1812
# Episode 88, Total Reward: 26.0, Steps: 1838
# Episode 89, Total Reward: 11.0, Steps: 1849
# Episode 90, Total Reward: 10.0, Steps: 1859
# Episode 91, Total Reward: 21.0, Steps: 1880
# Episode 92, Total Reward: 27.0, Steps: 1907
# Episode 93, Total Reward: 28.0, Steps: 1935
# Episode 94, Total Reward: 40.0, Steps: 1975
# Episode 95, Total Reward: 13.0, Steps: 1988
# Episode 96, Total Reward: 16.0, Steps: 2004
# Episode 97, Total Reward: 12.0, Steps: 2016
# Episode 98, Total Reward: 12.0, Steps: 2028
# Episode 99, Total Reward: 42.0, Steps: 2070
# Episode 100, Total Reward: 23.0, Steps: 2093
# Episode 101, Total Reward: 36.0, Steps: 2129
# Episode 102, Total Reward: 25.0, Steps: 2154
# Episode 103, Total Reward: 27.0, Steps: 2181
# Episode 104, Total Reward: 30.0, Steps: 2211
# Episode 105, Total Reward: 9.0, Steps: 2220
# Episode 106, Total Reward: 17.0, Steps: 2237
# Episode 107, Total Reward: 21.0, Steps: 2258
# Episode 108, Total Reward: 16.0, Steps: 2274
# Episode 109, Total Reward: 22.0, Steps: 2296
# Episode 110, Total Reward: 26.0, Steps: 2322
# Episode 111, Total Reward: 33.0, Steps: 2355
# Episode 112, Total Reward: 18.0, Steps: 2373
# Episode 113, Total Reward: 10.0, Steps: 2383
# Episode 114, Total Reward: 20.0, Steps: 2403
# Episode 115, Total Reward: 13.0, Steps: 2416
# Episode 116, Total Reward: 24.0, Steps: 2440
# Episode 117, Total Reward: 14.0, Steps: 2454
# Episode 118, Total Reward: 31.0, Steps: 2485
# Episode 119, Total Reward: 28.0, Steps: 2513
# Episode 120, Total Reward: 18.0, Steps: 2531
# Episode 121, Total Reward: 16.0, Steps: 2547
# Episode 122, Total Reward: 20.0, Steps: 2567
# Episode 123, Total Reward: 11.0, Steps: 2578
# Episode 124, Total Reward: 17.0, Steps: 2595
# Episode 125, Total Reward: 34.0, Steps: 2629
# Episode 126, Total Reward: 27.0, Steps: 2656
# Episode 127, Total Reward: 19.0, Steps: 2675
# Episode 128, Total Reward: 11.0, Steps: 2686
# Episode 129, Total Reward: 41.0, Steps: 2727
# Episode 130, Total Reward: 26.0, Steps: 2753
# Episode 131, Total Reward: 16.0, Steps: 2769
# Episode 132, Total Reward: 38.0, Steps: 2807
# Episode 133, Total Reward: 17.0, Steps: 2824
# Episode 134, Total Reward: 13.0, Steps: 2837
# Episode 135, Total Reward: 16.0, Steps: 2853
# Episode 136, Total Reward: 26.0, Steps: 2879
# Episode 137, Total Reward: 37.0, Steps: 2916
# Episode 138, Total Reward: 21.0, Steps: 2937
# Episode 139, Total Reward: 30.0, Steps: 2967
# Episode 140, Total Reward: 19.0, Steps: 2986
# Episode 141, Total Reward: 21.0, Steps: 3007
# Episode 142, Total Reward: 15.0, Steps: 3022
# Episode 143, Total Reward: 24.0, Steps: 3046
# Episode 144, Total Reward: 25.0, Steps: 3071
# Episode 145, Total Reward: 36.0, Steps: 3107
# Episode 146, Total Reward: 27.0, Steps: 3134
# Episode 147, Total Reward: 21.0, Steps: 3155
# Episode 148, Total Reward: 82.0, Steps: 3237
# Episode 149, Total Reward: 23.0, Steps: 3260
# Episode 150, Total Reward: 15.0, Steps: 3275
# Episode 151, Total Reward: 22.0, Steps: 3297
# Episode 152, Total Reward: 74.0, Steps: 3371
# Episode 153, Total Reward: 22.0, Steps: 3393
# Episode 154, Total Reward: 19.0, Steps: 3412
# Episode 155, Total Reward: 29.0, Steps: 3441
# Episode 156, Total Reward: 17.0, Steps: 3458
# Episode 157, Total Reward: 15.0, Steps: 3473
# Episode 158, Total Reward: 18.0, Steps: 3491
# Episode 159, Total Reward: 11.0, Steps: 3502
# Episode 160, Total Reward: 12.0, Steps: 3514
# Episode 161, Total Reward: 10.0, Steps: 3524
# Episode 162, Total Reward: 14.0, Steps: 3538
# Episode 163, Total Reward: 15.0, Steps: 3553
# Episode 164, Total Reward: 19.0, Steps: 3572
# Episode 165, Total Reward: 15.0, Steps: 3587
# Episode 166, Total Reward: 12.0, Steps: 3599
# Episode 167, Total Reward: 53.0, Steps: 3652
# Episode 168, Total Reward: 40.0, Steps: 3692
# Episode 169, Total Reward: 18.0, Steps: 3710
# Episode 170, Total Reward: 19.0, Steps: 3729
# Episode 171, Total Reward: 24.0, Steps: 3753
# Episode 172, Total Reward: 12.0, Steps: 3765
# Episode 173, Total Reward: 21.0, Steps: 3786
# Episode 174, Total Reward: 24.0, Steps: 3810
# Episode 175, Total Reward: 22.0, Steps: 3832
# Episode 176, Total Reward: 42.0, Steps: 3874
# Episode 177, Total Reward: 30.0, Steps: 3904
# Episode 178, Total Reward: 15.0, Steps: 3919
# Episode 179, Total Reward: 14.0, Steps: 3933
# Episode 180, Total Reward: 32.0, Steps: 3965
# Episode 181, Total Reward: 19.0, Steps: 3984
# Episode 182, Total Reward: 19.0, Steps: 4003
# Episode 183, Total Reward: 14.0, Steps: 4017
# Episode 184, Total Reward: 53.0, Steps: 4070
# Episode 185, Total Reward: 37.0, Steps: 4107
# Episode 186, Total Reward: 38.0, Steps: 4145
# Episode 187, Total Reward: 15.0, Steps: 4160
# Episode 188, Total Reward: 12.0, Steps: 4172
# Episode 189, Total Reward: 29.0, Steps: 4201
# Episode 190, Total Reward: 14.0, Steps: 4215
# Episode 191, Total Reward: 13.0, Steps: 4228
# Episode 192, Total Reward: 11.0, Steps: 4239
# Episode 193, Total Reward: 14.0, Steps: 4253
# Episode 194, Total Reward: 11.0, Steps: 4264
# Episode 195, Total Reward: 15.0, Steps: 4279
# Episode 196, Total Reward: 26.0, Steps: 4305
# Episode 197, Total Reward: 29.0, Steps: 4334
# Episode 198, Total Reward: 20.0, Steps: 4354
# Episode 199, Total Reward: 53.0, Steps: 4407
# Episode 200, Total Reward: 21.0, Steps: 4428
# Episode 201, Total Reward: 16.0, Steps: 4444
# Episode 202, Total Reward: 15.0, Steps: 4459
# Episode 203, Total Reward: 19.0, Steps: 4478
# Episode 204, Total Reward: 13.0, Steps: 4491
# Episode 205, Total Reward: 29.0, Steps: 4520
# Episode 206, Total Reward: 15.0, Steps: 4535
# Episode 207, Total Reward: 19.0, Steps: 4554
# Episode 208, Total Reward: 18.0, Steps: 4572
# Episode 209, Total Reward: 22.0, Steps: 4594
# Episode 210, Total Reward: 19.0, Steps: 4613
# Episode 211, Total Reward: 10.0, Steps: 4623
# Episode 212, Total Reward: 11.0, Steps: 4634
# Episode 213, Total Reward: 16.0, Steps: 4650
# Episode 214, Total Reward: 28.0, Steps: 4678
# Episode 215, Total Reward: 11.0, Steps: 4689
# Episode 216, Total Reward: 15.0, Steps: 4704
# Episode 217, Total Reward: 17.0, Steps: 4721
# Episode 218, Total Reward: 28.0, Steps: 4749
# Episode 219, Total Reward: 37.0, Steps: 4786
# Episode 220, Total Reward: 22.0, Steps: 4808
# Episode 221, Total Reward: 13.0, Steps: 4821
# Episode 222, Total Reward: 19.0, Steps: 4840
# Episode 223, Total Reward: 10.0, Steps: 4850
# Episode 224, Total Reward: 22.0, Steps: 4872
# Episode 225, Total Reward: 13.0, Steps: 4885
# Episode 226, Total Reward: 16.0, Steps: 4901
# Episode 227, Total Reward: 38.0, Steps: 4939
# Episode 228, Total Reward: 11.0, Steps: 4950
# Episode 229, Total Reward: 26.0, Steps: 4976
# Episode 230, Total Reward: 16.0, Steps: 4992
# Episode 231, Total Reward: 17.0, Steps: 5009
# Episode 232, Total Reward: 16.0, Steps: 5025
# Episode 233, Total Reward: 21.0, Steps: 5046
# Episode 234, Total Reward: 13.0, Steps: 5059
# Episode 235, Total Reward: 13.0, Steps: 5072
# Episode 236, Total Reward: 12.0, Steps: 5084
# Episode 237, Total Reward: 25.0, Steps: 5109
# Episode 238, Total Reward: 18.0, Steps: 5127
# Episode 239, Total Reward: 12.0, Steps: 5139
# Episode 240, Total Reward: 32.0, Steps: 5171
# Episode 241, Total Reward: 12.0, Steps: 5183
# Episode 242, Total Reward: 47.0, Steps: 5230
# Episode 243, Total Reward: 11.0, Steps: 5241
# Episode 244, Total Reward: 14.0, Steps: 5255
# Episode 245, Total Reward: 12.0, Steps: 5267
# Episode 246, Total Reward: 18.0, Steps: 5285
# Episode 247, Total Reward: 12.0, Steps: 5297
# Episode 248, Total Reward: 27.0, Steps: 5324
# Episode 249, Total Reward: 13.0, Steps: 5337
# Episode 250, Total Reward: 23.0, Steps: 5360
# Episode 251, Total Reward: 20.0, Steps: 5380
# Episode 252, Total Reward: 14.0, Steps: 5394
# Episode 253, Total Reward: 25.0, Steps: 5419
# Episode 254, Total Reward: 12.0, Steps: 5431
# Episode 255, Total Reward: 12.0, Steps: 5443
# Episode 256, Total Reward: 37.0, Steps: 5480
# Episode 257, Total Reward: 10.0, Steps: 5490
# Episode 258, Total Reward: 21.0, Steps: 5511
# Episode 259, Total Reward: 11.0, Steps: 5522
# Episode 260, Total Reward: 11.0, Steps: 5533
# Episode 261, Total Reward: 18.0, Steps: 5551
# Episode 262, Total Reward: 30.0, Steps: 5581
# Episode 263, Total Reward: 19.0, Steps: 5600
# Episode 264, Total Reward: 16.0, Steps: 5616
# Episode 265, Total Reward: 12.0, Steps: 5628
# Episode 266, Total Reward: 15.0, Steps: 5643
# Episode 267, Total Reward: 10.0, Steps: 5653
# Episode 268, Total Reward: 29.0, Steps: 5682
# Episode 269, Total Reward: 15.0, Steps: 5697
# Episode 270, Total Reward: 17.0, Steps: 5714
# Episode 271, Total Reward: 20.0, Steps: 5734
# Episode 272, Total Reward: 10.0, Steps: 5744
# Episode 273, Total Reward: 25.0, Steps: 5769
# Episode 274, Total Reward: 43.0, Steps: 5812
# Episode 275, Total Reward: 20.0, Steps: 5832
# Episode 276, Total Reward: 19.0, Steps: 5851
# Episode 277, Total Reward: 42.0, Steps: 5893
# Episode 278, Total Reward: 37.0, Steps: 5930
# Episode 279, Total Reward: 17.0, Steps: 5947
# Episode 280, Total Reward: 27.0, Steps: 5974
# Episode 281, Total Reward: 28.0, Steps: 6002
# Episode 282, Total Reward: 21.0, Steps: 6023
# Episode 283, Total Reward: 24.0, Steps: 6047
# Episode 284, Total Reward: 15.0, Steps: 6062
# Episode 285, Total Reward: 17.0, Steps: 6079
# Episode 286, Total Reward: 36.0, Steps: 6115
# Episode 287, Total Reward: 26.0, Steps: 6141
# Episode 288, Total Reward: 12.0, Steps: 6153
# Episode 289, Total Reward: 16.0, Steps: 6169
# Episode 290, Total Reward: 25.0, Steps: 6194
# Episode 291, Total Reward: 14.0, Steps: 6208
# Episode 292, Total Reward: 21.0, Steps: 6229
# Episode 293, Total Reward: 25.0, Steps: 6254
# Episode 294, Total Reward: 10.0, Steps: 6264
# Episode 295, Total Reward: 14.0, Steps: 6278
# Episode 296, Total Reward: 33.0, Steps: 6311
# Episode 297, Total Reward: 9.0, Steps: 6320
# Episode 298, Total Reward: 23.0, Steps: 6343
# Episode 299, Total Reward: 20.0, Steps: 6363
# Episode 300, Total Reward: 20.0, Steps: 6383
# Episode 301, Total Reward: 41.0, Steps: 6424
# Episode 302, Total Reward: 18.0, Steps: 6442
# Episode 303, Total Reward: 19.0, Steps: 6461
# Episode 304, Total Reward: 29.0, Steps: 6490
# Episode 305, Total Reward: 41.0, Steps: 6531
# Episode 306, Total Reward: 19.0, Steps: 6550
# Episode 307, Total Reward: 16.0, Steps: 6566
# Episode 308, Total Reward: 27.0, Steps: 6593
# Episode 309, Total Reward: 14.0, Steps: 6607
# Episode 310, Total Reward: 17.0, Steps: 6624
# Episode 311, Total Reward: 14.0, Steps: 6638
# Episode 312, Total Reward: 32.0, Steps: 6670
# Episode 313, Total Reward: 16.0, Steps: 6686
# Episode 314, Total Reward: 26.0, Steps: 6712
# Episode 315, Total Reward: 17.0, Steps: 6729
# Episode 316, Total Reward: 12.0, Steps: 6741
# Episode 317, Total Reward: 20.0, Steps: 6761
# Episode 318, Total Reward: 23.0, Steps: 6784
# Episode 319, Total Reward: 15.0, Steps: 6799
# Episode 320, Total Reward: 29.0, Steps: 6828
# Episode 321, Total Reward: 19.0, Steps: 6847
# Episode 322, Total Reward: 43.0, Steps: 6890
# Episode 323, Total Reward: 14.0, Steps: 6904
# Episode 324, Total Reward: 18.0, Steps: 6922
# Episode 325, Total Reward: 28.0, Steps: 6950
# Episode 326, Total Reward: 21.0, Steps: 6971
# Episode 327, Total Reward: 13.0, Steps: 6984
# Episode 328, Total Reward: 24.0, Steps: 7008
# Episode 329, Total Reward: 33.0, Steps: 7041
# Episode 330, Total Reward: 15.0, Steps: 7056
# Episode 331, Total Reward: 12.0, Steps: 7068
# Episode 332, Total Reward: 13.0, Steps: 7081
# Episode 333, Total Reward: 13.0, Steps: 7094
# Episode 334, Total Reward: 34.0, Steps: 7128
# Episode 335, Total Reward: 28.0, Steps: 7156
# Episode 336, Total Reward: 27.0, Steps: 7183
# Episode 337, Total Reward: 26.0, Steps: 7209
# Episode 338, Total Reward: 40.0, Steps: 7249
# Episode 339, Total Reward: 23.0, Steps: 7272
# Episode 340, Total Reward: 16.0, Steps: 7288
# Episode 341, Total Reward: 22.0, Steps: 7310
# Episode 342, Total Reward: 26.0, Steps: 7336
# Episode 343, Total Reward: 17.0, Steps: 7353
# Episode 344, Total Reward: 12.0, Steps: 7365
# Episode 345, Total Reward: 18.0, Steps: 7383
# Episode 346, Total Reward: 27.0, Steps: 7410
# Episode 347, Total Reward: 19.0, Steps: 7429
# Episode 348, Total Reward: 19.0, Steps: 7448
# Episode 349, Total Reward: 41.0, Steps: 7489
# Episode 350, Total Reward: 19.0, Steps: 7508
# Episode 351, Total Reward: 14.0, Steps: 7522
# Episode 352, Total Reward: 30.0, Steps: 7552
# Episode 353, Total Reward: 24.0, Steps: 7576
# Episode 354, Total Reward: 16.0, Steps: 7592
# Episode 355, Total Reward: 24.0, Steps: 7616
# Episode 356, Total Reward: 12.0, Steps: 7628
# Episode 357, Total Reward: 27.0, Steps: 7655
# Episode 358, Total Reward: 15.0, Steps: 7670
# Episode 359, Total Reward: 14.0, Steps: 7684
# Episode 360, Total Reward: 27.0, Steps: 7711
# Episode 361, Total Reward: 25.0, Steps: 7736
# Episode 362, Total Reward: 21.0, Steps: 7757
# Episode 363, Total Reward: 18.0, Steps: 7775
# Episode 364, Total Reward: 19.0, Steps: 7794
# Episode 365, Total Reward: 12.0, Steps: 7806
# Episode 366, Total Reward: 23.0, Steps: 7829
# Episode 367, Total Reward: 24.0, Steps: 7853
# Episode 368, Total Reward: 53.0, Steps: 7906
# Episode 369, Total Reward: 22.0, Steps: 7928
# Episode 370, Total Reward: 30.0, Steps: 7958
# Episode 371, Total Reward: 12.0, Steps: 7970
# Episode 372, Total Reward: 30.0, Steps: 8000
# Episode 373, Total Reward: 75.0, Steps: 8075
# Episode 374, Total Reward: 10.0, Steps: 8085
# Episode 375, Total Reward: 42.0, Steps: 8127
# Episode 376, Total Reward: 14.0, Steps: 8141
# Episode 377, Total Reward: 36.0, Steps: 8177
# Episode 378, Total Reward: 12.0, Steps: 8189
# Episode 379, Total Reward: 38.0, Steps: 8227
# Episode 380, Total Reward: 24.0, Steps: 8251
# Episode 381, Total Reward: 10.0, Steps: 8261
# Episode 382, Total Reward: 30.0, Steps: 8291
# Episode 383, Total Reward: 10.0, Steps: 8301
# Episode 384, Total Reward: 34.0, Steps: 8335
# Episode 385, Total Reward: 18.0, Steps: 8353
# Episode 386, Total Reward: 13.0, Steps: 8366
# Episode 387, Total Reward: 17.0, Steps: 8383
# Episode 388, Total Reward: 17.0, Steps: 8400
# Episode 389, Total Reward: 13.0, Steps: 8413
# Episode 390, Total Reward: 23.0, Steps: 8436
# Episode 391, Total Reward: 12.0, Steps: 8448
# Episode 392, Total Reward: 22.0, Steps: 8470
# Episode 393, Total Reward: 26.0, Steps: 8496
# Episode 394, Total Reward: 52.0, Steps: 8548
# Episode 395, Total Reward: 16.0, Steps: 8564
# Episode 396, Total Reward: 21.0, Steps: 8585
# Episode 397, Total Reward: 27.0, Steps: 8612
# Episode 398, Total Reward: 21.0, Steps: 8633
# Episode 399, Total Reward: 12.0, Steps: 8645
# Episode 400, Total Reward: 57.0, Steps: 8702
# Episode 401, Total Reward: 48.0, Steps: 8750
# Episode 402, Total Reward: 19.0, Steps: 8769
# Episode 403, Total Reward: 22.0, Steps: 8791
# Episode 404, Total Reward: 20.0, Steps: 8811
# Episode 405, Total Reward: 29.0, Steps: 8840
# Episode 406, Total Reward: 32.0, Steps: 8872
# Episode 407, Total Reward: 11.0, Steps: 8883
# Episode 408, Total Reward: 42.0, Steps: 8925
# Episode 409, Total Reward: 23.0, Steps: 8948
# Episode 410, Total Reward: 10.0, Steps: 8958
# Episode 411, Total Reward: 19.0, Steps: 8977
# Episode 412, Total Reward: 29.0, Steps: 9006
# Episode 413, Total Reward: 22.0, Steps: 9028
# Episode 414, Total Reward: 18.0, Steps: 9046
# Episode 415, Total Reward: 10.0, Steps: 9056
# Episode 416, Total Reward: 9.0, Steps: 9065
# Episode 417, Total Reward: 15.0, Steps: 9080
# Episode 418, Total Reward: 49.0, Steps: 9129
# Episode 419, Total Reward: 28.0, Steps: 9157
# Episode 420, Total Reward: 14.0, Steps: 9171
# Episode 421, Total Reward: 11.0, Steps: 9182
# Episode 422, Total Reward: 13.0, Steps: 9195
# Episode 423, Total Reward: 38.0, Steps: 9233
# Episode 424, Total Reward: 19.0, Steps: 9252
# Episode 425, Total Reward: 14.0, Steps: 9266
# Episode 426, Total Reward: 13.0, Steps: 9279
# Episode 427, Total Reward: 28.0, Steps: 9307
# Episode 428, Total Reward: 10.0, Steps: 9317
# Episode 429, Total Reward: 8.0, Steps: 9325
# Episode 430, Total Reward: 23.0, Steps: 9348
# Episode 431, Total Reward: 19.0, Steps: 9367
# Episode 432, Total Reward: 17.0, Steps: 9384
# Episode 433, Total Reward: 15.0, Steps: 9399
# Episode 434, Total Reward: 29.0, Steps: 9428
# Episode 435, Total Reward: 17.0, Steps: 9445
# Episode 436, Total Reward: 12.0, Steps: 9457
# Episode 437, Total Reward: 14.0, Steps: 9471
# Episode 438, Total Reward: 15.0, Steps: 9486
# Episode 439, Total Reward: 17.0, Steps: 9503
# Episode 440, Total Reward: 15.0, Steps: 9518
# Episode 441, Total Reward: 34.0, Steps: 9552
# Episode 442, Total Reward: 34.0, Steps: 9586
# Episode 443, Total Reward: 19.0, Steps: 9605
# Episode 444, Total Reward: 31.0, Steps: 9636
# Episode 445, Total Reward: 29.0, Steps: 9665
# Episode 446, Total Reward: 29.0, Steps: 9694
# Episode 447, Total Reward: 14.0, Steps: 9708
# Episode 448, Total Reward: 28.0, Steps: 9736
# Episode 449, Total Reward: 13.0, Steps: 9749
# Episode 450, Total Reward: 63.0, Steps: 9812
# Episode 451, Total Reward: 12.0, Steps: 9824
# Episode 452, Total Reward: 11.0, Steps: 9835
# Episode 453, Total Reward: 32.0, Steps: 9867
# Episode 454, Total Reward: 23.0, Steps: 9890
# Episode 455, Total Reward: 19.0, Steps: 9909
# Episode 456, Total Reward: 17.0, Steps: 9926
# Episode 457, Total Reward: 12.0, Steps: 9938
# Episode 458, Total Reward: 13.0, Steps: 9951
# Episode 459, Total Reward: 42.0, Steps: 9993
# Episode 460, Total Reward: 16.0, Steps: 10009
# Episode 461, Total Reward: 15.0, Steps: 10024
# Episode 462, Total Reward: 68.0, Steps: 10092
# Episode 463, Total Reward: 8.0, Steps: 10100
# Episode 464, Total Reward: 21.0, Steps: 10121
# Episode 465, Total Reward: 9.0, Steps: 10130
# Episode 466, Total Reward: 42.0, Steps: 10172
# Episode 467, Total Reward: 23.0, Steps: 10195
# Episode 468, Total Reward: 46.0, Steps: 10241
# Episode 469, Total Reward: 15.0, Steps: 10256
# Episode 470, Total Reward: 19.0, Steps: 10275
# Episode 471, Total Reward: 17.0, Steps: 10292
# Episode 472, Total Reward: 9.0, Steps: 10301
# Episode 473, Total Reward: 19.0, Steps: 10320
# Episode 474, Total Reward: 13.0, Steps: 10333
# Episode 475, Total Reward: 21.0, Steps: 10354
# Episode 476, Total Reward: 43.0, Steps: 10397
# Episode 477, Total Reward: 13.0, Steps: 10410
# Episode 478, Total Reward: 35.0, Steps: 10445
# Episode 479, Total Reward: 20.0, Steps: 10465
# Episode 480, Total Reward: 29.0, Steps: 10494
# Episode 481, Total Reward: 17.0, Steps: 10511
# Episode 482, Total Reward: 14.0, Steps: 10525
# Episode 483, Total Reward: 17.0, Steps: 10542
# Episode 484, Total Reward: 58.0, Steps: 10600
# Episode 485, Total Reward: 26.0, Steps: 10626
# Episode 486, Total Reward: 31.0, Steps: 10657
# Episode 487, Total Reward: 21.0, Steps: 10678
# Episode 488, Total Reward: 9.0, Steps: 10687
# Episode 489, Total Reward: 12.0, Steps: 10699
# Episode 490, Total Reward: 30.0, Steps: 10729
# Episode 491, Total Reward: 20.0, Steps: 10749
# Episode 492, Total Reward: 38.0, Steps: 10787
# Episode 493, Total Reward: 18.0, Steps: 10805
# Episode 494, Total Reward: 15.0, Steps: 10820
# Episode 495, Total Reward: 44.0, Steps: 10864
# Episode 496, Total Reward: 21.0, Steps: 10885
# Episode 497, Total Reward: 26.0, Steps: 10911
# Episode 498, Total Reward: 18.0, Steps: 10929
# Episode 499, Total Reward: 20.0, Steps: 10949
# Episode 500, Total Reward: 18.0, Steps: 10967
# Episode 501, Total Reward: 13.0, Steps: 10980
# Episode 502, Total Reward: 20.0, Steps: 11000
# Episode 503, Total Reward: 43.0, Steps: 11043
# Episode 504, Total Reward: 21.0, Steps: 11064
# Episode 505, Total Reward: 17.0, Steps: 11081
# Episode 506, Total Reward: 17.0, Steps: 11098
# Episode 507, Total Reward: 15.0, Steps: 11113
# Episode 508, Total Reward: 28.0, Steps: 11141
# Episode 509, Total Reward: 19.0, Steps: 11160
# Episode 510, Total Reward: 16.0, Steps: 11176
# Episode 511, Total Reward: 21.0, Steps: 11197
# Episode 512, Total Reward: 10.0, Steps: 11207
# Episode 513, Total Reward: 22.0, Steps: 11229
# Episode 514, Total Reward: 19.0, Steps: 11248
# Episode 515, Total Reward: 14.0, Steps: 11262
# Episode 516, Total Reward: 24.0, Steps: 11286
# Episode 517, Total Reward: 10.0, Steps: 11296
# Episode 518, Total Reward: 17.0, Steps: 11313
# Episode 519, Total Reward: 16.0, Steps: 11329
# Episode 520, Total Reward: 14.0, Steps: 11343
# Episode 521, Total Reward: 43.0, Steps: 11386
# Episode 522, Total Reward: 18.0, Steps: 11404
# Episode 523, Total Reward: 21.0, Steps: 11425
# Episode 524, Total Reward: 42.0, Steps: 11467
# Episode 525, Total Reward: 17.0, Steps: 11484
# Episode 526, Total Reward: 47.0, Steps: 11531
# Episode 527, Total Reward: 15.0, Steps: 11546
# Episode 528, Total Reward: 23.0, Steps: 11569
# Episode 529, Total Reward: 25.0, Steps: 11594
# Episode 530, Total Reward: 74.0, Steps: 11668
# Episode 531, Total Reward: 12.0, Steps: 11680
# Episode 532, Total Reward: 11.0, Steps: 11691
# Episode 533, Total Reward: 14.0, Steps: 11705
# Episode 534, Total Reward: 14.0, Steps: 11719
# Episode 535, Total Reward: 19.0, Steps: 11738
# Episode 536, Total Reward: 24.0, Steps: 11762
# Episode 537, Total Reward: 29.0, Steps: 11791
# Episode 538, Total Reward: 37.0, Steps: 11828
# Episode 539, Total Reward: 35.0, Steps: 11863
# Episode 540, Total Reward: 18.0, Steps: 11881
# Episode 541, Total Reward: 11.0, Steps: 11892
# Episode 542, Total Reward: 46.0, Steps: 11938
# Episode 543, Total Reward: 14.0, Steps: 11952
# Episode 544, Total Reward: 13.0, Steps: 11965
# Episode 545, Total Reward: 24.0, Steps: 11989
# Episode 546, Total Reward: 19.0, Steps: 12008
# Episode 547, Total Reward: 18.0, Steps: 12026
# Episode 548, Total Reward: 17.0, Steps: 12043
# Episode 549, Total Reward: 19.0, Steps: 12062
# Episode 550, Total Reward: 27.0, Steps: 12089
# Episode 551, Total Reward: 27.0, Steps: 12116
# Episode 552, Total Reward: 19.0, Steps: 12135
# Episode 553, Total Reward: 17.0, Steps: 12152
# Episode 554, Total Reward: 13.0, Steps: 12165
# Episode 555, Total Reward: 31.0, Steps: 12196
# Episode 556, Total Reward: 33.0, Steps: 12229
# Episode 557, Total Reward: 12.0, Steps: 12241
# Episode 558, Total Reward: 23.0, Steps: 12264
# Episode 559, Total Reward: 10.0, Steps: 12274
# Episode 560, Total Reward: 28.0, Steps: 12302
# Episode 561, Total Reward: 17.0, Steps: 12319
# Episode 562, Total Reward: 22.0, Steps: 12341
# Episode 563, Total Reward: 18.0, Steps: 12359
# Episode 564, Total Reward: 11.0, Steps: 12370
# Episode 565, Total Reward: 36.0, Steps: 12406
# Episode 566, Total Reward: 15.0, Steps: 12421
# Episode 567, Total Reward: 11.0, Steps: 12432
# Episode 568, Total Reward: 20.0, Steps: 12452
# Episode 569, Total Reward: 19.0, Steps: 12471
# Episode 570, Total Reward: 19.0, Steps: 12490
# Episode 571, Total Reward: 14.0, Steps: 12504
# Episode 572, Total Reward: 30.0, Steps: 12534
# Episode 573, Total Reward: 13.0, Steps: 12547
# Episode 574, Total Reward: 14.0, Steps: 12561
# Episode 575, Total Reward: 20.0, Steps: 12581
# Episode 576, Total Reward: 37.0, Steps: 12618
# Episode 577, Total Reward: 22.0, Steps: 12640
# Episode 578, Total Reward: 11.0, Steps: 12651
# Episode 579, Total Reward: 43.0, Steps: 12694
# Episode 580, Total Reward: 19.0, Steps: 12713
# Episode 581, Total Reward: 16.0, Steps: 12729
# Episode 582, Total Reward: 20.0, Steps: 12749
# Episode 583, Total Reward: 34.0, Steps: 12783
# Episode 584, Total Reward: 25.0, Steps: 12808
# Episode 585, Total Reward: 16.0, Steps: 12824
# Episode 586, Total Reward: 14.0, Steps: 12838
# Episode 587, Total Reward: 16.0, Steps: 12854
# Episode 588, Total Reward: 18.0, Steps: 12872
# Episode 589, Total Reward: 21.0, Steps: 12893
# Episode 590, Total Reward: 14.0, Steps: 12907
# Episode 591, Total Reward: 10.0, Steps: 12917
# Episode 592, Total Reward: 12.0, Steps: 12929
# Episode 593, Total Reward: 35.0, Steps: 12964
# Episode 594, Total Reward: 27.0, Steps: 12991
# Episode 595, Total Reward: 16.0, Steps: 13007
# Episode 596, Total Reward: 32.0, Steps: 13039
# Episode 597, Total Reward: 13.0, Steps: 13052
# Episode 598, Total Reward: 13.0, Steps: 13065
# Episode 599, Total Reward: 30.0, Steps: 13095
# Episode 600, Total Reward: 14.0, Steps: 13109
# Episode 601, Total Reward: 18.0, Steps: 13127
# Episode 602, Total Reward: 15.0, Steps: 13142
# Episode 603, Total Reward: 21.0, Steps: 13163
# Episode 604, Total Reward: 10.0, Steps: 13173
# Episode 605, Total Reward: 33.0, Steps: 13206
# Episode 606, Total Reward: 12.0, Steps: 13218
# Episode 607, Total Reward: 14.0, Steps: 13232
# Episode 608, Total Reward: 11.0, Steps: 13243
# Episode 609, Total Reward: 18.0, Steps: 13261
# Episode 610, Total Reward: 24.0, Steps: 13285
# Episode 611, Total Reward: 22.0, Steps: 13307
# Episode 612, Total Reward: 27.0, Steps: 13334
# Episode 613, Total Reward: 10.0, Steps: 13344
# Episode 614, Total Reward: 15.0, Steps: 13359
# Episode 615, Total Reward: 32.0, Steps: 13391
# Episode 616, Total Reward: 13.0, Steps: 13404
# Episode 617, Total Reward: 18.0, Steps: 13422
# Episode 618, Total Reward: 22.0, Steps: 13444
# Episode 619, Total Reward: 20.0, Steps: 13464
# Episode 620, Total Reward: 32.0, Steps: 13496
# Episode 621, Total Reward: 16.0, Steps: 13512
# Episode 622, Total Reward: 14.0, Steps: 13526
# Episode 623, Total Reward: 8.0, Steps: 13534
# Episode 624, Total Reward: 51.0, Steps: 13585
# Episode 625, Total Reward: 13.0, Steps: 13598
# Episode 626, Total Reward: 27.0, Steps: 13625
# Episode 627, Total Reward: 13.0, Steps: 13638
# Episode 628, Total Reward: 24.0, Steps: 13662
# Episode 629, Total Reward: 19.0, Steps: 13681
# Episode 630, Total Reward: 13.0, Steps: 13694
# Episode 631, Total Reward: 22.0, Steps: 13716
# Episode 632, Total Reward: 14.0, Steps: 13730
# Episode 633, Total Reward: 21.0, Steps: 13751
# Episode 634, Total Reward: 21.0, Steps: 13772
# Episode 635, Total Reward: 22.0, Steps: 13794
# Episode 636, Total Reward: 19.0, Steps: 13813
# Episode 637, Total Reward: 31.0, Steps: 13844
# Episode 638, Total Reward: 19.0, Steps: 13863
# Episode 639, Total Reward: 12.0, Steps: 13875
# Episode 640, Total Reward: 30.0, Steps: 13905
# Episode 641, Total Reward: 12.0, Steps: 13917
# Episode 642, Total Reward: 14.0, Steps: 13931
# Episode 643, Total Reward: 42.0, Steps: 13973
# Episode 644, Total Reward: 13.0, Steps: 13986
# Episode 645, Total Reward: 19.0, Steps: 14005
# Episode 646, Total Reward: 14.0, Steps: 14019
# Episode 647, Total Reward: 48.0, Steps: 14067
# Episode 648, Total Reward: 15.0, Steps: 14082
# Episode 649, Total Reward: 16.0, Steps: 14098
# Episode 650, Total Reward: 36.0, Steps: 14134
# Episode 651, Total Reward: 9.0, Steps: 14143
# Episode 652, Total Reward: 26.0, Steps: 14169
# Episode 653, Total Reward: 11.0, Steps: 14180
# Episode 654, Total Reward: 25.0, Steps: 14205
# Episode 655, Total Reward: 29.0, Steps: 14234
# Episode 656, Total Reward: 24.0, Steps: 14258
# Episode 657, Total Reward: 23.0, Steps: 14281
# Episode 658, Total Reward: 23.0, Steps: 14304
# Episode 659, Total Reward: 15.0, Steps: 14319
# Episode 660, Total Reward: 32.0, Steps: 14351
# Episode 661, Total Reward: 11.0, Steps: 14362
# Episode 662, Total Reward: 27.0, Steps: 14389
# Episode 663, Total Reward: 13.0, Steps: 14402
# Episode 664, Total Reward: 9.0, Steps: 14411
# Episode 665, Total Reward: 16.0, Steps: 14427
# Episode 666, Total Reward: 14.0, Steps: 14441
# Episode 667, Total Reward: 14.0, Steps: 14455
# Episode 668, Total Reward: 60.0, Steps: 14515
# Episode 669, Total Reward: 11.0, Steps: 14526
# Episode 670, Total Reward: 22.0, Steps: 14548
# Episode 671, Total Reward: 13.0, Steps: 14561
# Episode 672, Total Reward: 16.0, Steps: 14577
# Episode 673, Total Reward: 13.0, Steps: 14590
# Episode 674, Total Reward: 34.0, Steps: 14624
# Episode 675, Total Reward: 20.0, Steps: 14644
# Episode 676, Total Reward: 24.0, Steps: 14668
# Episode 677, Total Reward: 30.0, Steps: 14698
# Episode 678, Total Reward: 20.0, Steps: 14718
# Episode 679, Total Reward: 11.0, Steps: 14729
# Episode 680, Total Reward: 13.0, Steps: 14742
# Episode 681, Total Reward: 12.0, Steps: 14754
# Episode 682, Total Reward: 25.0, Steps: 14779
# Episode 683, Total Reward: 10.0, Steps: 14789
# Episode 684, Total Reward: 12.0, Steps: 14801
# Episode 685, Total Reward: 16.0, Steps: 14817
# Episode 686, Total Reward: 12.0, Steps: 14829
# Episode 687, Total Reward: 26.0, Steps: 14855
# Episode 688, Total Reward: 22.0, Steps: 14877
# Episode 689, Total Reward: 20.0, Steps: 14897
# Episode 690, Total Reward: 28.0, Steps: 14925
# Episode 691, Total Reward: 13.0, Steps: 14938
# Episode 692, Total Reward: 21.0, Steps: 14959
# Episode 693, Total Reward: 17.0, Steps: 14976
# Episode 694, Total Reward: 45.0, Steps: 15021
# Episode 695, Total Reward: 39.0, Steps: 15060
# Episode 696, Total Reward: 15.0, Steps: 15075
# Episode 697, Total Reward: 18.0, Steps: 15093
# Episode 698, Total Reward: 17.0, Steps: 15110
# Episode 699, Total Reward: 32.0, Steps: 15142
# Episode 700, Total Reward: 26.0, Steps: 15168
# Episode 701, Total Reward: 21.0, Steps: 15189
# Episode 702, Total Reward: 15.0, Steps: 15204
# Episode 703, Total Reward: 9.0, Steps: 15213
# Episode 704, Total Reward: 21.0, Steps: 15234
# Episode 705, Total Reward: 42.0, Steps: 15276
# Episode 706, Total Reward: 13.0, Steps: 15289
# Episode 707, Total Reward: 30.0, Steps: 15319
# Episode 708, Total Reward: 17.0, Steps: 15336
# Episode 709, Total Reward: 36.0, Steps: 15372
# Episode 710, Total Reward: 21.0, Steps: 15393
# Episode 711, Total Reward: 13.0, Steps: 15406
# Episode 712, Total Reward: 19.0, Steps: 15425
# Episode 713, Total Reward: 26.0, Steps: 15451
# Episode 714, Total Reward: 16.0, Steps: 15467
# Episode 715, Total Reward: 15.0, Steps: 15482
# Episode 716, Total Reward: 11.0, Steps: 15493
# Episode 717, Total Reward: 32.0, Steps: 15525
# Episode 718, Total Reward: 10.0, Steps: 15535
# Episode 719, Total Reward: 17.0, Steps: 15552
# Episode 720, Total Reward: 10.0, Steps: 15562
# Episode 721, Total Reward: 14.0, Steps: 15576
# Episode 722, Total Reward: 17.0, Steps: 15593
# Episode 723, Total Reward: 16.0, Steps: 15609
# Episode 724, Total Reward: 17.0, Steps: 15626
# Episode 725, Total Reward: 12.0, Steps: 15638
# Episode 726, Total Reward: 24.0, Steps: 15662
# Episode 727, Total Reward: 30.0, Steps: 15692
# Episode 728, Total Reward: 17.0, Steps: 15709
# Episode 729, Total Reward: 22.0, Steps: 15731
# Episode 730, Total Reward: 17.0, Steps: 15748
# Episode 731, Total Reward: 13.0, Steps: 15761
# Episode 732, Total Reward: 13.0, Steps: 15774
# Episode 733, Total Reward: 25.0, Steps: 15799
# Episode 734, Total Reward: 23.0, Steps: 15822
# Episode 735, Total Reward: 16.0, Steps: 15838
# Episode 736, Total Reward: 27.0, Steps: 15865
# Episode 737, Total Reward: 18.0, Steps: 15883
# Episode 738, Total Reward: 26.0, Steps: 15909
# Episode 739, Total Reward: 23.0, Steps: 15932
# Episode 740, Total Reward: 9.0, Steps: 15941
# Episode 741, Total Reward: 18.0, Steps: 15959
# Episode 742, Total Reward: 24.0, Steps: 15983
# Episode 743, Total Reward: 16.0, Steps: 15999
# Episode 744, Total Reward: 29.0, Steps: 16028
# Episode 745, Total Reward: 16.0, Steps: 16044
# Episode 746, Total Reward: 14.0, Steps: 16058
# Episode 747, Total Reward: 15.0, Steps: 16073
# Episode 748, Total Reward: 26.0, Steps: 16099
# Episode 749, Total Reward: 15.0, Steps: 16114
# Episode 750, Total Reward: 19.0, Steps: 16133
# Episode 751, Total Reward: 34.0, Steps: 16167
# Episode 752, Total Reward: 14.0, Steps: 16181
# Episode 753, Total Reward: 18.0, Steps: 16199
# Episode 754, Total Reward: 24.0, Steps: 16223
# Episode 755, Total Reward: 24.0, Steps: 16247
# Episode 756, Total Reward: 20.0, Steps: 16267
# Episode 757, Total Reward: 11.0, Steps: 16278
# Episode 758, Total Reward: 21.0, Steps: 16299
# Episode 759, Total Reward: 18.0, Steps: 16317
# Episode 760, Total Reward: 20.0, Steps: 16337
# Episode 761, Total Reward: 16.0, Steps: 16353
# Episode 762, Total Reward: 20.0, Steps: 16373
# Episode 763, Total Reward: 23.0, Steps: 16396
# Episode 764, Total Reward: 13.0, Steps: 16409
# Episode 765, Total Reward: 36.0, Steps: 16445
# Episode 766, Total Reward: 19.0, Steps: 16464
# Episode 767, Total Reward: 11.0, Steps: 16475
# Episode 768, Total Reward: 9.0, Steps: 16484
# Episode 769, Total Reward: 31.0, Steps: 16515
# Episode 770, Total Reward: 15.0, Steps: 16530
# Episode 771, Total Reward: 27.0, Steps: 16557
# Episode 772, Total Reward: 17.0, Steps: 16574
# Episode 773, Total Reward: 9.0, Steps: 16583
# Episode 774, Total Reward: 13.0, Steps: 16596
# Episode 775, Total Reward: 24.0, Steps: 16620
# Episode 776, Total Reward: 16.0, Steps: 16636
# Episode 777, Total Reward: 10.0, Steps: 16646
# Episode 778, Total Reward: 16.0, Steps: 16662
# Episode 779, Total Reward: 10.0, Steps: 16672
# Episode 780, Total Reward: 15.0, Steps: 16687
# Episode 781, Total Reward: 32.0, Steps: 16719
# Episode 782, Total Reward: 16.0, Steps: 16735
# Episode 783, Total Reward: 17.0, Steps: 16752
# Episode 784, Total Reward: 12.0, Steps: 16764
# Episode 785, Total Reward: 19.0, Steps: 16783
# Episode 786, Total Reward: 19.0, Steps: 16802
# Episode 787, Total Reward: 25.0, Steps: 16827
# Episode 788, Total Reward: 15.0, Steps: 16842
# Episode 789, Total Reward: 17.0, Steps: 16859
# Episode 790, Total Reward: 14.0, Steps: 16873
# Episode 791, Total Reward: 16.0, Steps: 16889
# Episode 792, Total Reward: 20.0, Steps: 16909
# Episode 793, Total Reward: 66.0, Steps: 16975
# Episode 794, Total Reward: 18.0, Steps: 16993
# Episode 795, Total Reward: 14.0, Steps: 17007
# Episode 796, Total Reward: 15.0, Steps: 17022
# Episode 797, Total Reward: 59.0, Steps: 17081
# Episode 798, Total Reward: 24.0, Steps: 17105
# Episode 799, Total Reward: 24.0, Steps: 17129
# Episode 800, Total Reward: 27.0, Steps: 17156
# Episode 801, Total Reward: 25.0, Steps: 17181
# Episode 802, Total Reward: 16.0, Steps: 17197
# Episode 803, Total Reward: 18.0, Steps: 17215
# Episode 804, Total Reward: 15.0, Steps: 17230
# Episode 805, Total Reward: 35.0, Steps: 17265
# Episode 806, Total Reward: 31.0, Steps: 17296
# Episode 807, Total Reward: 16.0, Steps: 17312
# Episode 808, Total Reward: 21.0, Steps: 17333
# Episode 809, Total Reward: 27.0, Steps: 17360
# Episode 810, Total Reward: 15.0, Steps: 17375
# Episode 811, Total Reward: 27.0, Steps: 17402
# Episode 812, Total Reward: 12.0, Steps: 17414
# Episode 813, Total Reward: 14.0, Steps: 17428
# Episode 814, Total Reward: 11.0, Steps: 17439
# Episode 815, Total Reward: 13.0, Steps: 17452
# Episode 816, Total Reward: 11.0, Steps: 17463
# Episode 817, Total Reward: 15.0, Steps: 17478
# Episode 818, Total Reward: 12.0, Steps: 17490
# Episode 819, Total Reward: 23.0, Steps: 17513
# Episode 820, Total Reward: 12.0, Steps: 17525
# Episode 821, Total Reward: 23.0, Steps: 17548
# Episode 822, Total Reward: 20.0, Steps: 17568
# Episode 823, Total Reward: 22.0, Steps: 17590
# Episode 824, Total Reward: 16.0, Steps: 17606
# Episode 825, Total Reward: 21.0, Steps: 17627
# Episode 826, Total Reward: 24.0, Steps: 17651
# Episode 827, Total Reward: 17.0, Steps: 17668
# Episode 828, Total Reward: 19.0, Steps: 17687
# Episode 829, Total Reward: 17.0, Steps: 17704
# Episode 830, Total Reward: 19.0, Steps: 17723
# Episode 831, Total Reward: 35.0, Steps: 17758
# Episode 832, Total Reward: 20.0, Steps: 17778
# Episode 833, Total Reward: 13.0, Steps: 17791
# Episode 834, Total Reward: 13.0, Steps: 17804
# Episode 835, Total Reward: 26.0, Steps: 17830
# Episode 836, Total Reward: 53.0, Steps: 17883
# Episode 837, Total Reward: 42.0, Steps: 17925
# Episode 838, Total Reward: 13.0, Steps: 17938
# Episode 839, Total Reward: 37.0, Steps: 17975
# Episode 840, Total Reward: 40.0, Steps: 18015
# Episode 841, Total Reward: 19.0, Steps: 18034
# Episode 842, Total Reward: 13.0, Steps: 18047
# Episode 843, Total Reward: 26.0, Steps: 18073
# Episode 844, Total Reward: 13.0, Steps: 18086
# Episode 845, Total Reward: 18.0, Steps: 18104
# Episode 846, Total Reward: 28.0, Steps: 18132
# Episode 847, Total Reward: 14.0, Steps: 18146
# Episode 848, Total Reward: 14.0, Steps: 18160
# Episode 849, Total Reward: 29.0, Steps: 18189
# Episode 850, Total Reward: 20.0, Steps: 18209
# Episode 851, Total Reward: 18.0, Steps: 18227
# Episode 852, Total Reward: 22.0, Steps: 18249
# Episode 853, Total Reward: 10.0, Steps: 18259
# Episode 854, Total Reward: 29.0, Steps: 18288
# Episode 855, Total Reward: 32.0, Steps: 18320
# Episode 856, Total Reward: 9.0, Steps: 18329
# Episode 857, Total Reward: 11.0, Steps: 18340
# Episode 858, Total Reward: 28.0, Steps: 18368
# Episode 859, Total Reward: 13.0, Steps: 18381
# Episode 860, Total Reward: 16.0, Steps: 18397
# Episode 861, Total Reward: 15.0, Steps: 18412
# Episode 862, Total Reward: 16.0, Steps: 18428
# Episode 863, Total Reward: 30.0, Steps: 18458
# Episode 864, Total Reward: 12.0, Steps: 18470
# Episode 865, Total Reward: 11.0, Steps: 18481
# Episode 866, Total Reward: 9.0, Steps: 18490
# Episode 867, Total Reward: 11.0, Steps: 18501
# Episode 868, Total Reward: 19.0, Steps: 18520
# Episode 869, Total Reward: 10.0, Steps: 18530
# Episode 870, Total Reward: 17.0, Steps: 18547
# Episode 871, Total Reward: 14.0, Steps: 18561
# Episode 872, Total Reward: 18.0, Steps: 18579
# Episode 873, Total Reward: 16.0, Steps: 18595
# Episode 874, Total Reward: 10.0, Steps: 18605
# Episode 875, Total Reward: 14.0, Steps: 18619
# Episode 876, Total Reward: 39.0, Steps: 18658
# Episode 877, Total Reward: 25.0, Steps: 18683
# Episode 878, Total Reward: 21.0, Steps: 18704
# Episode 879, Total Reward: 14.0, Steps: 18718
# Episode 880, Total Reward: 31.0, Steps: 18749
# Episode 881, Total Reward: 43.0, Steps: 18792
# Episode 882, Total Reward: 35.0, Steps: 18827
# Episode 883, Total Reward: 23.0, Steps: 18850
# Episode 884, Total Reward: 11.0, Steps: 18861
# Episode 885, Total Reward: 43.0, Steps: 18904
# Episode 886, Total Reward: 17.0, Steps: 18921
# Episode 887, Total Reward: 28.0, Steps: 18949
# Episode 888, Total Reward: 29.0, Steps: 18978
# Episode 889, Total Reward: 20.0, Steps: 18998
# Episode 890, Total Reward: 24.0, Steps: 19022
# Episode 891, Total Reward: 13.0, Steps: 19035
# Episode 892, Total Reward: 20.0, Steps: 19055
# Episode 893, Total Reward: 27.0, Steps: 19082
# Episode 894, Total Reward: 14.0, Steps: 19096
# Episode 895, Total Reward: 12.0, Steps: 19108
# Episode 896, Total Reward: 14.0, Steps: 19122
# Episode 897, Total Reward: 21.0, Steps: 19143
# Episode 898, Total Reward: 11.0, Steps: 19154
# Episode 899, Total Reward: 10.0, Steps: 19164
# Episode 900, Total Reward: 11.0, Steps: 19175
# Episode 901, Total Reward: 16.0, Steps: 19191
# Episode 902, Total Reward: 65.0, Steps: 19256
# Episode 903, Total Reward: 16.0, Steps: 19272
# Episode 904, Total Reward: 17.0, Steps: 19289
# Episode 905, Total Reward: 22.0, Steps: 19311
# Episode 906, Total Reward: 34.0, Steps: 19345
# Episode 907, Total Reward: 17.0, Steps: 19362
# Episode 908, Total Reward: 14.0, Steps: 19376
# Episode 909, Total Reward: 18.0, Steps: 19394
# Episode 910, Total Reward: 16.0, Steps: 19410
# Episode 911, Total Reward: 22.0, Steps: 19432
# Episode 912, Total Reward: 22.0, Steps: 19454
# Episode 913, Total Reward: 12.0, Steps: 19466
# Episode 914, Total Reward: 39.0, Steps: 19505
# Episode 915, Total Reward: 20.0, Steps: 19525
# Episode 916, Total Reward: 24.0, Steps: 19549
# Episode 917, Total Reward: 29.0, Steps: 19578
# Episode 918, Total Reward: 26.0, Steps: 19604
# Episode 919, Total Reward: 15.0, Steps: 19619
# Episode 920, Total Reward: 27.0, Steps: 19646
# Episode 921, Total Reward: 11.0, Steps: 19657
# Episode 922, Total Reward: 34.0, Steps: 19691
# Episode 923, Total Reward: 18.0, Steps: 19709
# Episode 924, Total Reward: 14.0, Steps: 19723
# Episode 925, Total Reward: 18.0, Steps: 19741
# Episode 926, Total Reward: 38.0, Steps: 19779
# Episode 927, Total Reward: 13.0, Steps: 19792
# Episode 928, Total Reward: 15.0, Steps: 19807
# Episode 929, Total Reward: 27.0, Steps: 19834
# Episode 930, Total Reward: 14.0, Steps: 19848
# Episode 931, Total Reward: 51.0, Steps: 19899
# Episode 932, Total Reward: 11.0, Steps: 19910
# Episode 933, Total Reward: 12.0, Steps: 19922
# Episode 934, Total Reward: 18.0, Steps: 19940
# Episode 935, Total Reward: 8.0, Steps: 19948
# Episode 936, Total Reward: 14.0, Steps: 19962
# Episode 937, Total Reward: 23.0, Steps: 19985
# Episode 938, Total Reward: 15.0, Steps: 20000
# Episode 939, Total Reward: 14.0, Steps: 20014
# Episode 940, Total Reward: 17.0, Steps: 20031
# Episode 941, Total Reward: 50.0, Steps: 20081
# Episode 942, Total Reward: 18.0, Steps: 20099
# Episode 943, Total Reward: 10.0, Steps: 20109
# Episode 944, Total Reward: 16.0, Steps: 20125
# Episode 945, Total Reward: 32.0, Steps: 20157
# Episode 946, Total Reward: 10.0, Steps: 20167
# Episode 947, Total Reward: 12.0, Steps: 20179
# Episode 948, Total Reward: 13.0, Steps: 20192
# Episode 949, Total Reward: 24.0, Steps: 20216
# Episode 950, Total Reward: 43.0, Steps: 20259
# Episode 951, Total Reward: 71.0, Steps: 20330
# Episode 952, Total Reward: 12.0, Steps: 20342
# Episode 953, Total Reward: 21.0, Steps: 20363
# Episode 954, Total Reward: 28.0, Steps: 20391
# Episode 955, Total Reward: 17.0, Steps: 20408
# Episode 956, Total Reward: 21.0, Steps: 20429
# Episode 957, Total Reward: 16.0, Steps: 20445
# Episode 958, Total Reward: 13.0, Steps: 20458
# Episode 959, Total Reward: 20.0, Steps: 20478
# Episode 960, Total Reward: 22.0, Steps: 20500
# Episode 961, Total Reward: 30.0, Steps: 20530
# Episode 962, Total Reward: 11.0, Steps: 20541
# Episode 963, Total Reward: 18.0, Steps: 20559
# Episode 964, Total Reward: 14.0, Steps: 20573
# Episode 965, Total Reward: 39.0, Steps: 20612
# Episode 966, Total Reward: 13.0, Steps: 20625
# Episode 967, Total Reward: 15.0, Steps: 20640
# Episode 968, Total Reward: 11.0, Steps: 20651
# Episode 969, Total Reward: 18.0, Steps: 20669
# Episode 970, Total Reward: 32.0, Steps: 20701
# Episode 971, Total Reward: 19.0, Steps: 20720
# Episode 972, Total Reward: 15.0, Steps: 20735
# Episode 973, Total Reward: 13.0, Steps: 20748
# Episode 974, Total Reward: 20.0, Steps: 20768
# Episode 975, Total Reward: 37.0, Steps: 20805
# Episode 976, Total Reward: 21.0, Steps: 20826
# Episode 977, Total Reward: 33.0, Steps: 20859
# Episode 978, Total Reward: 26.0, Steps: 20885
# Episode 979, Total Reward: 17.0, Steps: 20902
# Episode 980, Total Reward: 15.0, Steps: 20917
# Episode 981, Total Reward: 11.0, Steps: 20928
# Episode 982, Total Reward: 15.0, Steps: 20943
# Episode 983, Total Reward: 13.0, Steps: 20956
# Episode 984, Total Reward: 25.0, Steps: 20981
# Episode 985, Total Reward: 17.0, Steps: 20998
# Episode 986, Total Reward: 15.0, Steps: 21013
# Episode 987, Total Reward: 16.0, Steps: 21029
# Episode 988, Total Reward: 14.0, Steps: 21043
# Episode 989, Total Reward: 14.0, Steps: 21057
# Episode 990, Total Reward: 16.0, Steps: 21073
# Episode 991, Total Reward: 16.0, Steps: 21089
# Episode 992, Total Reward: 29.0, Steps: 21118
# Episode 993, Total Reward: 25.0, Steps: 21143
# Episode 994, Total Reward: 9.0, Steps: 21152
# Episode 995, Total Reward: 29.0, Steps: 21181
# Episode 996, Total Reward: 16.0, Steps: 21197
# Episode 997, Total Reward: 12.0, Steps: 21209
# Episode 998, Total Reward: 25.0, Steps: 21234
# Episode 999, Total Reward: 18.0, Steps: 21252

# %%
def play_game(agent, env):
    frame_stack = deque(maxlen=4)
    frame, _ = env.reset()
    frame = preprocess_frame(frame)

    for _ in range(4):
        frame_stack.append(frame)

    total_reward = 0
    done = False
    truncated = False

    while not (done or truncated):
        state = np.array(frame_stack)
        action = agent.select_greedy_action(state)

        next_frame, reward, done, truncated, _ = env.step(action)
        next_frame = preprocess_frame(next_frame)
        frame_stack.append(next_frame)

        total_reward += reward

    return total_reward

# %%
# plot the losses
plt.plot(losses)
plt.xlabel("Steps")
plt.ylabel("Total Reward")
plt.title("Total Reward per Episode vs Steps")
plt.show()
